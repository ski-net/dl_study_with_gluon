# %%
from keras.layers import Input, Dense
from keras.models import Model

# this is the size of our encoded representations
# encoding_dim = 32  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

# this is our input placeholder
input_img = Input(shape=(784,))
# "enbcoded" is the encoded representation of the input
encoded_1 = Dense(128, activation='relu')(input_img)
encoded_2 = Dense(64, activation='relu')(encoded_1)
encoded_3 = Dense(12, activation='relu')(encoded_2)

# "decoded" is the lossy reconstruction of the input
decoded_1 = Dense(12, activation='relu')(encoded_3)
decoded_2 = Dense(64, activation='relu')(encoded_1)
decoded_3 = Dense(128, activation='relu')(decoded_2)
decoded_4 = Dense(28*28, activation='tanh')(decoded_3)

# this model maps an input to its reconstruction
autoencoder = Model(input_img, decoded_4)
# Out:
# Using TensorFlow backend.

# %%
from keras.utils import plot_model
plot_model(autoencoder, show_shapes = True, show_layer_names = False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# //anaconda/envs/py35/lib/python3.5/site-packages/pydot.py in create(self, prog, format, encoding)
#    1860                 shell=False,
# -> 1861                 stderr=subprocess.PIPE, stdout=subprocess.PIPE)
#    1862         except OSError as e:
#
# //anaconda/envs/py35/lib/python3.5/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds)
#     946                                 errread, errwrite,
# --> 947                                 restore_signals, start_new_session)
#     948         except:
#
# ...

# %%
# this model maps an input to its encoded representation
encoder = Model(input_img, encoded)

# %%
# create a placeholder for an encoded (32-dimensional) input
encoded_input = Input(shape=(12,))
# retrieve the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-1]
# create the decoder model
decoder = Model(encoded_input, decoder_layer(encoded_input))

# %%
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')

# %%
from keras.datasets import mnist
import numpy as np
(x_train, _), (x_test, _) = mnist.load_data()

# %%
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %%
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 2s - loss: 0.4879 - val_loss: 0.3364
# Epoch 2/50
# 60000/60000 [==============================] - 1s - loss: 0.3064 - val_loss: 0.2823
# Epoch 3/50
# 60000/60000 [==============================] - 1s - loss: 0.2607 - val_loss: 0.2419
# Epoch 4/50
# 60000/60000 [==============================] - 1s - loss: 0.2335 - val_loss: 0.2230
# Epoch 5/50
# 60000/60000 [==============================] - 1s - loss: 0.2193 - val_loss: 0.2124
# Epoch 6/50
# 60000/60000 [==============================] - 2s - loss: 0.2103 - val_loss: 0.2044
# Epoch 7/50
# 60000/60000 [==============================] - 1s - loss: 0.2026 - val_loss: 0.1973
# Epoch 8/50
# 60000/60000 [==============================] - 1s - loss: 0.1967 - val_loss: 0.1926
# Epoch 9/50
# 60000/60000 [==============================] - 1s - loss: 0.1915 - val_loss: 0.1875
# Epoch 10/50
# ...

# %%
x_test.shape
# Out:
# (10000, 784)

# %%
# encode and decode some digits
# note that we take them from the *test* set
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

# %%
decoded_imgs[0]
# Out:
# array([-0.49300769, -0.78736031, -0.60200793, -0.74801129, -0.94619328,
#        -0.26262739, -0.60168695, -0.5884105 , -0.46972138, -0.68602735,
#        -0.52894223, -0.75203568, -0.7295208 , -0.73633277, -0.35125035,
#        -0.37962443, -0.81743526, -0.84610146, -0.57243699, -0.75026965,
#        -0.51699227, -0.37459013, -0.88344598, -0.78938711, -0.49420652,
#        -0.60921347, -0.55228311, -0.47862169, -0.56359774, -0.80070305,
#        -0.54311073, -0.84190089, -0.82062352, -0.93494189, -0.31967306,
#        -0.89429057, -0.63601124, -0.65171415, -0.85359085, -0.42172429,
#        -0.78146076, -0.74040389, -0.28291446, -0.76014036, -0.79693305,
#        -0.56352574, -0.63061553, -0.5425871 , -0.60368443, -0.62775326,
#        -0.72728372, -0.61783993, -0.66928232, -0.45565265, -0.51466918,
#        -0.69173217, -0.87232542, -0.57671833, -0.62255061, -0.67291743,
#        -0.61973304, -0.24010772, -0.8759445 , -0.67501742, -0.78640723,
# ...

# %%
decoded_imgs[1]
# Out:
# array([-0.64933288, -0.9476679 , -0.92117345, -0.85594648, -0.97968817,
#        -0.68351477, -0.83300465, -0.7852084 , -0.78913462, -0.91263843,
#        -0.62802386, -0.66845262, -0.67857718, -0.88857496, -0.55399871,
#        -0.55656099, -0.94136208, -0.97271365, -0.84370291, -0.88957149,
#        -0.41929108, -0.81834853, -0.97820008, -0.56097877, -0.67061657,
#        -0.92308742, -0.68871403, -0.61976194, -0.44925734, -0.81999779,
#        -0.5004248 , -0.91863215, -0.83396357, -0.97099322, -0.67839873,
#        -0.97216445, -0.93181348, -0.86441487, -0.864663  , -0.85560858,
#        -0.32535255, -0.90411544, -0.55955815, -0.91903287, -0.74897212,
#        -0.35094658, -0.44513661, -0.85960913, -0.79135942, -0.68067122,
#        -0.89800197, -0.40094361, -0.85465479, -0.85838079, -0.52714401,
#        -0.96066815, -0.97985595, -0.71086878, -0.76470613, -0.72513688,
#        -0.80016005, -0.6002627 , -0.71678239, -0.83541316, -0.94167906,
# ...

# %%
decoded_imgs = decoded_imgs.astype('float32') / 255

# %%
# use Matplotlib (don't ask)
import matplotlib.pyplot as plt

n = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
decoded_imgs.shape
# Out:
# (10000, 784)
